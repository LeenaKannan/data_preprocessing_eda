# %%
import numpy as np
marks=[45,36,75,89,99,56,90,68,87,54,45,98,67,74]
five_number=np.quantile(marks,[0,0.25,0.5,0.75,1])

# %%
iqr=five_number[3]-five_number[1]
iqr
# Out:
# 34.0

# %%
lower_fence = five_number[1]-1.5*iqr
higher_fence=five_number[3]+1.5*iqr

# %%
lower_fence,higher_fence
# Out:
# (3.5, 139.5)

# %%
import seaborn as sns 
sns.boxplot(marks)
# Out:
# <Axes: >

# %%
marks_with_outliers=marks+[-100,-200,167]

# %%
sns.boxplot(marks_with_outliers)
# Out:
# <Axes: >
